# %% [markdown]
# The identity function, a function that returns its argument

# %%
def identity(x):
    return x

# %%
identity(2)
# Out:
# 2

# %%
# In contrast, if you use a Python lambda construction, you get the fofo, , llowing:

# %%
lambda x: x
# Out:
# <function __main__.<lambda>(x)>

# %%
lambda x: x + 1
# Out:
# <function __main__.<lambda>(x)>

# %%
#You can apply the function above to an argument by surrounding the function and its argument with parentheses:

# %%
(lambda x: x)(4)
# Out:
# 4

# %%
(lambda x: x+1)(4)  #(lambda x: x + 1)(4) = lambda 4: 4 + 1 =5
# Out:
# 5

# %%
(lambda x: x *x)(3)
# Out:
# 9

# %%
add_one = lambda x: x + 1
add_one(3)
# Out:
# 4

# %%
def add_one(x):
    return x + 1

# %%
#These functions all take a single argument

# %%
## tile method for string:
str1 = 'geeKs foR geEks'
str2 = str1.title()

# %%
str2
# Out:
# 'Geeks For Geeks'

# %%
full_name = lambda first, last: f'Nome-Cognome: {first.title()} {last.title()}'

# %%
full_name('guido', 'van rossum')
# Out:
# 'Nome-Cognome: Guido Van Rossum'

# %%
# multiple argument
lambda x, y: x + y
# Out:
# <function __main__.<lambda>(x, y)>

# %%
(lambda x, y: x + y)(5, 6)
# Out:
# 11

# %%
(lambda x, y, z: x + y + z)(1, 2, 3)
# Out:
# 6

# %%
(lambda x, y, z=3: x + y + z)(1, 2)
# Out:
# 6

# %%
(lambda *args: sum(args))(1,2,3,4,5,6)
# Out:
# 21

# %%
(lambda x, y=0, z=0: x + y + z)(1, y=2, z=3)
# Out:
# 6

# %%
(lambda x, y=0, z=0: x + y + z)(1,y=32,z=1)
# Out:
# 34

# %%
(lambda x, y=0, z=0: x + y + z)(1,y=32,z=1,6)
# Out:
#   File "<ipython-input-21-d9ae16d63565>", line 1
#     (lambda x, y=0, z=0: x + y + z)(1,y=32,z=1,6)
#                                                 ^
# SyntaxError: positional argument follows keyword argument

# %%
def cube(y): 
    return y*y*y; 
    
print(cube(5)) 

g = lambda x: x*x*x 
print(g(5))
# Out:
# 125
# 125

# %% [markdown]
# map(f, list) → applies function f to all elements in list. Return a iterator of the result. (does not modify the original list)
# In python 3, they return a iterator object that represent the list.

# %%
# Return double of n 
def addition(n): 
    return n + n 
  
# We double all numbers using map() 
numbers = (1, 2, 3, 4) 
result = map(addition, numbers) 
print(list(result))
# Out:
# [2, 4, 6, 8]

# %%
numbers*2
# Out:
# (1, 2, 3, 4, 1, 2, 3, 4)

# %%
# Double all numbers using map and lambda 
  
numbers = (1, 2, 3, 4) 
result = map(lambda x: x + x, numbers) 
print(list(result))
# Out:
# [2, 4, 6, 8]

# %%
# Add two lists using map and lambda 
  
numbers1 = [1, 2, 3] 
numbers2 = [4, 5, 6] 
  
result = map(lambda x, y: x + y, numbers1, numbers2) 
print(list(result))
# Out:
# [5, 7, 9]

# %%
# List of strings 
lista = ['lune', 'marte'] 
  
# map() can listify the list of strings individually 
test = map(list, lista)
print(list(test))
# Out:
# [['l', 'u', 'n', 'e'], ['m', 'a', 'r', 't', 'e']]

# %%
lista1 = [5, 7, 22, 97, 54, 62, 77, 23, 73, 61]*2
lista1
# Out:
# [5, 7, 22, 97, 54, 62, 77, 23, 73, 61, 5, 7, 22, 97, 54, 62, 77, 23, 73, 61]

# %%
sorted(lista1, reverse=True)
# Out:
# [97, 97, 77, 77, 73, 73, 62, 62, 61, 61, 54, 54, 23, 23, 22, 22, 7, 7, 5, 5]

# %%
## double list values
lista1 = [5, 7, 22, 97, 54, 62, 77, 23, 73, 61] 
double_list = map(lambda x: x*2 , lista1)
print(list(double_list))
# Out:
# [10, 14, 44, 194, 108, 124, 154, 46, 146, 122]

# %%
# filter() with lambda() 
lista = [5, 7, 22, 97, 54, 62, 77, 23, 73, 61] 
lista_filt = list(filter(lambda x: (x%2 != 0) , lista)) 
print(lista_filt)
# Out:
# [5, 7, 97, 77, 23, 73, 61]

# %%
from functools import reduce
lista2 = [5, 8, 10, 20, 50, 100] 
somma_lista = reduce((lambda x, y: x + y), lista2) 
print (somma_lista)
# Out:
# 193

# %%
5+8+10+170
# Out:
# 193

# %%
import pandas as pd

# %%
df=pd.DataFrame({
    'id':[1,2,3,4,5],
    'name':['Jeremy','Frank','Janet','Ryan','Mary'],
    'age':[20,25,15,10,30],
    'income':[4000,7000,200,0,10000]
})
df
# Out:
#    id    name  age  income
# 0   1  Jeremy   20    4000
# 1   2   Frank   25    7000
# 2   3   Janet   15     200
# 3   4    Ryan   10       0
# 4   5    Mary   30   10000

# %%
df['age']=df.apply(lambda x: x['age']+3,axis=1)
df
# Out:
#    id    name  age  income
# 0   1  Jeremy   23    4000
# 1   2   Frank   28    7000
# 2   3   Janet   18     200
# 3   4    Ryan   13       0
# 4   5    Mary   33   10000

# %%
df['age']=df['age'].apply(lambda x: x+3)
df
# Out:
#    id    name  age  income
# 0   1  Jeremy   26    4000
# 1   2   Frank   31    7000
# 2   3   Janet   21     200
# 3   4    Ryan   16       0
# 4   5    Mary   36   10000

# %%
df['doubleAge']=df['age'].apply(lambda x:2*x)
df
# Out:
#    id    name  age  income  doubleAge
# 0   1  Jeremy   23    4000         46
# 1   2   Frank   28    7000         56
# 2   3   Janet   18     200         36
# 3   4    Ryan   13       0         26
# 4   5    Mary   33   10000         66

# %%
list(filter(lambda x: x>18,df['age']))
df
# Out:
#    id    name  age  income  doubleAge
# 0   1  Jeremy   23    4000         46
# 1   2   Frank   28    7000         56
# 2   3   Janet   18     200         36
# 3   4    Ryan   13       0         26
# 4   5    Mary   33   10000         66

# %%
df['income_perf20']=list(map(lambda x: int(x+x*0.2),df['income']))
df
# Out:
#    id    name  age  income  doubleAge  income_perf20
# 0   1  Jeremy   26    4000         52           4800
# 1   2   Frank   31    7000         62           8400
# 2   3   Janet   21     200         42            240
# 3   4    Ryan   16       0         32              0
# 4   5    Mary   36   10000         72          12000

# %%
df['category']=df['age'].apply(lambda x: 'Adult' if x>=18 else 'Child')
df
# Out:
#    id    name  age  income  doubleAge  income_perf20 category
# 0   1  Jeremy   26    4000         52           4800    Adult
# 1   2   Frank   31    7000         62           8400    Adult
# 2   3   Janet   21     200         42            240    Adult
# 3   4    Ryan   16       0         32              0    Child
# 4   5    Mary   36   10000         72          12000    Adult
