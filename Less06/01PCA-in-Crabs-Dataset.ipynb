# %% [markdown]
# ###  PCA Crabs Dataset

# %% [markdown]
# <img src="https://frenzy86.s3.eu-west-2.amazonaws.com/IFAO/crab.jpg" width="750" align="center">

# %%
# !wget https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/crabs.csv
# Out:
# --2023-04-14 08:08:06--  https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/crabs.csv
# Resolving frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)... 52.95.144.2
# Connecting to frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)|52.95.144.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10189 (10.0K) [text/csv]
# Saving to: ‘crabs.csv’
#
# crabs.csv           100%[===================>]   9.95K  --.-KB/s    in 0s
#
# 2023-04-14 08:08:07 (230 MB/s) - ‘crabs.csv’ saved [10189/10189]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from mpl_toolkits.mplot3d import Axes3D
import plotly.express as px

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Initial Study of the Dataset

# %%
df = pd.read_csv("crabs.csv")
df
# Out:
#     species     sex  index  Frontal Lobe  Rear Width  Carapace Midline  \
# 0      Blue    Male      1           8.1         6.7              16.1
# 1      Blue    Male      2           8.8         7.7              18.1
# 2      Blue    Male      3           9.2         7.8              19.0
# 3      Blue    Male      4           9.6         7.9              20.1
# 4      Blue    Male      5           9.8         8.0              20.3
# ..      ...     ...    ...           ...         ...               ...
# 195  Orange  Female     46          21.4        18.0              41.2
# 196  Orange  Female     47          21.7        17.1              41.7
# 197  Orange  Female     48          21.9        17.2              42.6
# 198  Orange  Female     49          22.5        17.2              43.0
# 199  Orange  Female     50          23.1        20.2              46.2
#
#      Maximum Width  Body Depth         class
# 0             19.0         7.0      BlueMale
# 1             20.8         7.4      BlueMale
# 2             22.4         7.7      BlueMale
# 3             23.1         8.2      BlueMale
# 4             23.0         8.2      BlueMale
# ..             ...         ...           ...
# 195           46.2        18.7  OrangeFemale
# 196           47.2        19.6  OrangeFemale
# 197           47.4        19.5  OrangeFemale
# 198           48.7        19.8  OrangeFemale
# 199           52.5        21.1  OrangeFemale
#
# [200 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   species           200 non-null    object
#  1   sex               200 non-null    object
#  2   index             200 non-null    int64
#  3   Frontal Lobe      200 non-null    float64
#  4   Rear Width        200 non-null    float64
#  5   Carapace Midline  200 non-null    float64
#  6   Maximum Width     200 non-null    float64
#  7   Body Depth        200 non-null    float64
#  8   class             200 non-null    object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 14.2+ KB

# %%
df.describe(include="all")
# Out:
#        species   sex       index  Frontal Lobe  Rear Width  Carapace Midline  \
# count      200   200  200.000000    200.000000   200.00000        200.000000
# unique       2     2         NaN           NaN         NaN               NaN
# top       Blue  Male         NaN           NaN         NaN               NaN
# freq       100   100         NaN           NaN         NaN               NaN
# mean       NaN   NaN   25.500000     15.583000    12.73850         32.105500
# std        NaN   NaN   14.467083      3.495325     2.57334          7.118983
# min        NaN   NaN    1.000000      7.200000     6.50000         14.700000
# 25%        NaN   NaN   13.000000     12.900000    11.00000         27.275000
# 50%        NaN   NaN   25.500000     15.550000    12.80000         32.100000
# 75%        NaN   NaN   38.000000     18.050000    14.30000         37.225000
# max        NaN   NaN   50.000000     23.100000    20.20000         47.600000
#
#         Maximum Width  Body Depth     class
# count      200.000000  200.000000       200
# unique            NaN         NaN         4
# top               NaN         NaN  BlueMale
# freq              NaN         NaN        50
# mean        36.414500   14.030500       NaN
# std          7.871955    3.424772       NaN
# min         17.100000    6.100000       NaN
# 25%         31.500000   11.400000       NaN
# 50%         36.800000   13.900000       NaN
# 75%         42.000000   16.600000       NaN
# max         54.600000   21.600000       NaN

# %%
df.describe().T
# Out:
#                   count     mean        std   min     25%    50%     75%   max
# index             200.0  25.5000  14.467083   1.0  13.000  25.50  38.000  50.0
# Frontal Lobe      200.0  15.5830   3.495325   7.2  12.900  15.55  18.050  23.1
# Rear Width        200.0  12.7385   2.573340   6.5  11.000  12.80  14.300  20.2
# Carapace Midline  200.0  32.1055   7.118983  14.7  27.275  32.10  37.225  47.6
# Maximum Width     200.0  36.4145   7.871955  17.1  31.500  36.80  42.000  54.6
# Body Depth        200.0  14.0305   3.424772   6.1  11.400  13.90  16.600  21.6

# %%
df.shape
# Out:
# (200, 9)

# %%
df['class'].value_counts()
# Out:
# BlueMale        50
# BlueFemale      50
# OrangeMale      50
# OrangeFemale    50
# Name: class, dtype: int64

# %%
df.corr()
# Out:
#                      index  Frontal Lobe  Rear Width  Carapace Midline  \
# index             1.000000      0.862876    0.840040          0.911436
# Frontal Lobe      0.862876      1.000000    0.906988          0.978842
# Rear Width        0.840040      0.906988    1.000000          0.892743
# Carapace Midline  0.911436      0.978842    0.892743          1.000000
# Maximum Width     0.928248      0.964956    0.900402          0.995023
# Body Depth        0.864459      0.987627    0.889205          0.983204
#
#                   Maximum Width  Body Depth
# index                  0.928248    0.864459
# Frontal Lobe           0.964956    0.987627
# Rear Width             0.900402    0.889205
# Carapace Midline       0.995023    0.983204
# Maximum Width          1.000000    0.967812
# Body Depth             0.967812    1.000000

# %%
## Selection only numerical features

data_columns = ['Frontal Lobe','Rear Width','Carapace Midline','Maximum Width','Body Depth']
df[data_columns].describe()
# Out:
#        Frontal Lobe  Rear Width  Carapace Midline  Maximum Width  Body Depth
# count    200.000000   200.00000        200.000000     200.000000  200.000000
# mean      15.583000    12.73850         32.105500      36.414500   14.030500
# std        3.495325     2.57334          7.118983       7.871955    3.424772
# min        7.200000     6.50000         14.700000      17.100000    6.100000
# 25%       12.900000    11.00000         27.275000      31.500000   11.400000
# 50%       15.550000    12.80000         32.100000      36.800000   13.900000
# 75%       18.050000    14.30000         37.225000      42.000000   16.600000
# max       23.100000    20.20000         47.600000      54.600000   21.600000

# %%
import seaborn as sns

sns.heatmap(df[data_columns].corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Boxplot of the relevant features.

# %%
fig, ax = plt.subplots(figsize=(8,5))
df[data_columns].boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ### Initial Visualization of the Classes

# %%
df.boxplot(column='Frontal Lobe', by = 'class', figsize=(8,5))
# Out:
# <Axes: title={'center': 'Frontal Lobe'}, xlabel='class'>

# %%
df.boxplot(column='Rear Width', by = 'class', figsize=(8,5))
# Out:
# <Axes: title={'center': 'Rear Width'}, xlabel='class'>

# %%
df.boxplot(column='Carapace Midline', by = 'class', figsize=(8,5))
# Out:
# <Axes: title={'center': 'Carapace Midline'}, xlabel='class'>

# %%
df.boxplot(column='Body Depth', by = 'class', figsize=(8,5))
# Out:
# <Axes: title={'center': 'Body Depth'}, xlabel='class'>

# %%
df.boxplot(column='Body Depth', by = 'class', figsize=(8,5))
# Out:
# <Axes: title={'center': 'Body Depth'}, xlabel='class'>

# %% [markdown]
# Histograms Study.

# %%
df[data_columns].hist(figsize=(16,4),layout=(1,6)) # layout = Tuple of (rows, columns) the histograms
# Out:
# array([[<Axes: title={'center': 'Frontal Lobe'}>,
#         <Axes: title={'center': 'Rear Width'}>,
#         <Axes: title={'center': 'Carapace Midline'}>,
#         <Axes: title={'center': 'Maximum Width'}>,
#         <Axes: title={'center': 'Body Depth'}>, <Axes: >]], dtype=object)

# %%
plt.figure(figsize=(8,6))
sns.histplot(df,x='Frontal Lobe',hue='class',bins=20)
# Out:
# <Axes: xlabel='Frontal Lobe', ylabel='Count'>

# %%
plt.figure(figsize=(8,6))
sns.histplot(df,x='Rear Width',hue='class',bins=20)
# Out:
# <Axes: xlabel='Rear Width', ylabel='Count'>

# %%
plt.figure(figsize=(8,6))
sns.histplot(df,x='Carapace Midline',hue='class',bins=20)
# Out:
# <Axes: xlabel='Carapace Midline', ylabel='Count'>

# %%
plt.figure(figsize=(8,6))
sns.histplot(df,x='Maximum Width',hue='class',bins=20)
# Out:
# <Axes: xlabel='Maximum Width', ylabel='Count'>

# %%
plt.figure(figsize=(8,6))
sns.histplot(df,x='Body Depth',hue='class',bins=20)
# Out:
# <Axes: xlabel='Body Depth', ylabel='Count'>

# %% [markdown]
# Pairplot: allows us to plot pairwise relationships between variables within a dataset

# %%
sns.pairplot(df.iloc[:,3:],hue='class')

# %% [markdown]
# ### Discussion for using PCA
# The high dimensionality of the data makes it difficult to manage and understand it.
#
# Dimensionality reduction methods allow
#
#
# *   Reduce unnecessary dimensions/noise
# *   Reduce the computational cost of learning
# *   Visualize data in 2D/3D

# %% [markdown]
# ## PCA
# Now we are going to use PCA to make a better visualization of our data.
#
# Data must be standardized in order to apply PCA.
# We will standardize it. This will change the data so that all variables have mean 0 and standard deviation 1.

# %% [markdown]
# <img src="https://frenzy86.s3.eu-west-2.amazonaws.com/IFAO/pca.jpg" width="750" align="center">

# %%
df_standardized = df.copy()
df_standardized[data_columns] = StandardScaler().fit_transform(df[data_columns])

# %%
df_standardized[data_columns].describe().T
# Out:
#                   count          mean       std       min       25%       50%  \
# Frontal Lobe      200.0 -7.105427e-17  1.002509 -2.404365 -0.769523 -0.009465
# Rear Width        200.0  6.039613e-16  1.002509 -2.430365 -0.677276  0.023959
# Carapace Midline  200.0  1.065814e-16  1.002509 -2.451077 -0.680241 -0.000775
# Maximum Width     200.0 -4.973799e-16  1.002509 -2.459741 -0.625872  0.049094
# Body Depth        200.0  0.000000e+00  1.002509 -2.321439 -0.770008 -0.038200
#
#                        75%       max
# Frontal Lobe      0.707571  2.155984
# Rear Width        0.608322  2.906815
# Carapace Midline  0.720938  2.181966
# Maximum Width     0.711325  2.315960
# Body Depth        0.752152  2.215766

# %% [markdown]
# Let's proceed to use PCA.
#
# The scikit-learn PCA method will return the explained variance ratio and all relevant PCA-related parameters.
#
# You can use the explained variance ratio and the singular values to decide how many components to keep.

# %%
df_standardized[data_columns].shape
# Out:
# (200, 5)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

myPCA = PCA().fit(df_standardized[data_columns])

print(myPCA.explained_variance_ratio_) # returns a vector of the variance explained by each dimension.

print(myPCA.explained_variance_ratio_.cumsum()) # vector x such that x[i] returns the cumulative variance explained by the first i+1 dimensions
# Out:
# [9.57766957e-01 3.03370413e-02 9.32659482e-03 2.22707143e-03
#  3.42335531e-04]
# [0.95776696 0.988104   0.99743059 0.99965766 1.        ]

# %%
myPCA.singular_values_
# Out:
# array([30.94781021,  5.50790717,  3.05394742,  1.49233757,  0.58509446])

# %% [markdown]
# #### Screeplot
# The scree plot is used to determine the number of
# principal components to keep in a principal component analysis (PCA).

# %%
fig = plt.figure(figsize=(8,6))
# Scree Plot
plt.plot(range(1,len(myPCA.singular_values_)+1),myPCA.singular_values_,alpha=0.8,marker='*')
y_label = plt.ylabel('EigenValues')
x_label = plt.xlabel('Components')
plt.title('Scree Plot')
# Out:
# Text(0.5, 1.0, 'Scree Plot')

# %% [markdown]
# #### % of Explained Variance by Component

# %%
fig = plt.figure(figsize=(8,6))
plt.plot(range(1,len(myPCA.explained_variance_ratio_)+1),myPCA.explained_variance_ratio_,alpha=0.8,marker='*', label="Explained Variance")
y_label = plt.ylabel("Explained Variance")
x_label = plt.xlabel("Components")
plt.plot(range(1,len(myPCA.explained_variance_ratio_ )+1),np.cumsum(myPCA.explained_variance_ratio_),c='r',marker='.',label="Cumulative Explained Variance")
plt.legend()
plt.title('Percentage of variance explained by component')
# Out:
# Text(0.5, 1.0, 'Percentage of variance explained by component')

# %%
# find the number od PC to describe the 96% of variability of the entire dataset

total_explained_variance = myPCA.explained_variance_ratio_.cumsum()
n_over_96 = len(total_explained_variance[total_explained_variance >= .96])
n_to_reach_96 = total_explained_variance.shape[0] - n_over_96 + 1
print(f"To explain 96% of variance with PCS, we need the first {n_to_reach_96} principal components")
# Out:
# To explain 96% of variance with PCS, we need the first 2 principal components

# %% [markdown]
# We can also visualize the weights that the PCA assigns to each component.

# %%
sns.heatmap(myPCA.components_,cmap='seismic',xticklabels = list(df.columns[3:-1]),
            vmin=-np.max(np.abs(myPCA.components_)),vmax=np.max(np.abs(myPCA.components_)),
            annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### PCA: Transformation and Visualization
# Now we can transform our dataset using the "trained" PCA.
#
# Generally, for visualization, 2 or 3 components are chosen.

# %% [markdown]
# We will choose 3 Components

# %%
transformed = myPCA.transform(df_standardized[data_columns])
## add the 3 Principal component coordinates to the dataset
df_standardized[['PC1','PC2','PC3']] = transformed[:,:3]

# %%
df_standardized.head()
# Out:
#   species   sex  index  Frontal Lobe  Rear Width  Carapace Midline  \
# 0    Blue  Male      1     -2.146232   -2.352450         -2.253926
# 1    Blue  Male      2     -1.945462   -1.962875         -1.972282
# 2    Blue  Male      3     -1.830736   -1.923917         -1.845543
# 3    Blue  Male      4     -1.716010   -1.884960         -1.690638
# 4    Blue  Male      5     -1.658647   -1.846002         -1.662474
#
#    Maximum Width  Body Depth     class       PC1       PC2       PC3
# 0      -2.217772   -2.057989  BlueMale  4.927573 -0.268445 -0.122258
# 1      -1.988538   -1.940899  BlueMale  4.386176 -0.094074 -0.039232
# 2      -1.784775   -1.853083  BlueMale  4.128664 -0.168876  0.033644
# 3      -1.695629   -1.706721  BlueMale  3.883681 -0.246008  0.014501
# 4      -1.708364   -1.706721  BlueMale  3.834055 -0.224166 -0.015067

# %% [markdown]
# Visualize First 2 Components of PCA

# %%
fig = plt.figure(figsize=(8,8))
sns.scatterplot(x='PC1',y='PC2',hue='class',data = df_standardized).set(title='PC1-PC2 class Plot')
# Out:
# [Text(0.5, 1.0, 'PC1-PC2 class Plot')]

# %% [markdown]
# We can see that PCA does a good job with this data.

# %% [markdown]
# #### Visualize with 3 Components of PCA

# %%
colors_crabs = {'BlueFemale': 'y', 'BlueMale': 'b', 'OrangeFemale': 'r', 'OrangeMale': 'g'}

fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111,projection='3d')

x = df_standardized.PC1
y = df_standardized.PC2
z = df_standardized.PC3
plt.scatter(x,y,zs=z,depthshade=False, 
            c=df['class'].apply(lambda x: colors_crabs[x]),s=100)

# %% [markdown]
# ### With Plotly

# %%
fig = px.scatter_3d(df_standardized,x='PC1',y='PC2',z='PC3',color = 'class')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="231c2f88-532c-4b43-94d0-7ee364d45ff0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("231c2f88-532c-4b43-94d0-7ee364d45ff0")) {                    Plotly.newPlot(                        "231c2f88-532c-4b43-94d0-7ee364d45ff0",                        [{"hovertemplate":"class=BlueMale<br>PC1=%{x}<br>PC2=%{y}<br>PC3=%{z}<extra></extra>","legendgroup":"BlueMale","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"BlueMale","scene":"scene","showlegend":true,"x":[4.927573145788268,4.386176390221365,4.12866384139662,3.8836811149940442,3.8340549180767263,2.952955114244526,2.6784423549984946,2.5484377804201803,2.5851789487756887,2.2058587264221994,1.7585771685948155,1.6838843108980375,1.7428294901908,1.7757384972290444,1.650266136713124,1.640562811416494,1.564385344525922,1.4758164788476227,1.4409812194351064,1.11074684307288,0.6358566318637137,0.4249375311209559,0.537722021861434,0.31296026223686335,0.20196955232962172,0.18417427536592207,0.11764067121494144,-0.5130754760831251,-0.32076084747463696,-0.18263880155568024,-0.7223014761418608,-0.9066850631715243,-0.6820729554346792,-0.8427728912273479,-1.1575568536126073,-0.8535727598116033,-1.1475916523370397,-0.9097801857448675,-1.0058863607438915,-1.3906324292231993,-1.5636011157045357,-1.8481257973781064,-1.6717497834642139,-2.786323203464725,-2.3437525439184284,-2.165347301561947,-2.778137483909441,-2.865208491291026,-2.7452526739294667,-4.025120616746594],"y":[-0.26844530364372016,-0.0940735864885835,-0.16887592389957284,-0.24600831758022573,-0.22416626928017608,-0.22002073281836423,0.039023078775510006,-0.3633831787236177,-0.11703765460048325,0.07916630492421982,-0.010298136808160245,0.0382340303316643,-0.3620898092679982,-0.24473044569763155,-0.008200124740223557,0.028357412359176482,-0.17362351135947482,-0.09020859738959754,-0.014673228474615248,-0.1761304707524125,-0.19331709611530634,-0.43085871577186735,-0.5290251572988925,-0.3861394800469373,-0.2700355453937398,-0.18889531862074393,-0.346595294047411,-0.31832220906901154,-0.1678215495035764,-0.5708117815175301,-0.33217937023829974,-0.20251921265259068,-0.3442034447476952,-0.29087126622465087,-0.22806266819186494,-0.37230826323110416,-0.3527102007575184,-0.4817534698688315,-0.49448328598667723,-0.337199234508249,-0.3695538865270351,-0.30447343060461357,-0.37846463069777087,-0.014402577119149705,-0.7831927518428715,-0.553711832979179,-0.20580716611057986,-0.7332351377391974,-0.6264158041489323,-0.6359279463200251],"z":[-0.12225775349800935,-0.03923188764478235,0.03364363385627124,0.014501021729037772,-0.01506731068921619,0.03842814874976623,0.08171026226772336,0.0625916513570174,0.06233839656176296,0.15697351311871868,0.3023715777612793,0.1931044406508055,0.19863824974818436,0.22049252389449306,0.1945771080299046,0.051901608629718425,0.24888029737113088,0.23700725388954966,0.16440627700197374,0.11344837553361287,0.2514691906132748,0.17563758996089784,0.15593479134514557,0.22626378583809392,0.22316802565785934,0.1433799596901085,0.20854535150260414,0.4046629948111363,0.21875386292944313,0.15681793634066019,0.1830289145905464,0.34013315046755105,0.30304275023992133,0.32945900987546356,0.5778966453369533,0.32835486177021206,0.3469584139178321,0.2811504317451773,0.22152779648658658,0.3506374046908184,0.38579502748356,0.3058238769675823,0.3281418074625242,0.5173557780670487,0.2757315127289677,0.30153251605934506,0.3277385670713654,0.3600234216036288,0.29803429672022974,0.5343613961147129],"type":"scatter3d"},{"hovertemplate":"class=BlueFemale<br>PC1=%{x}<br>PC2=%{y}<br>PC3=%{z}<extra></extra>","legendgroup":"BlueFemale","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"BlueFemale","scene":"scene","sh ...
